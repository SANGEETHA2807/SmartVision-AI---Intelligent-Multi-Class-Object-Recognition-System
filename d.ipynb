# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/351.2 MB 438.9 kB/s eta 0:13:20
#    ---------------------------------------- 0.5/351.2 MB 438.9 kB/s eta 0:13:20
#    ---------------------------------------- 0.5/351.2 MB 438.9 kB/s eta 0:13:20
#    ---------------------------------------- 0.8/351.2 MB 432.5 kB/s eta 0:13:31
#    ---------------------------------------- 0.8/351.2 MB 432.5 kB/s eta 0:13:31
#    ---------------------------------------- 0.8/351.2 MB 432.5 kB/s eta 0:13:31
# ...

# %%
import tensorflow as tf

model = tf.keras.models.load_model("mobilenetv2_model_v2.keras", compile=False)

print("Model loaded successfully")
model.summary()

# %%
import tensorflow as tf
print(tf.__version__)

# %%
# how is this requirements txt mean i only have app.py + best.pt + effcien + mobilenetv +resent+ vgg  and we need to uses only one modle by your using or puting all 4 mobel in the dshboard

# %%
pip install streamlit tensorflow pillow numpy opencv-python ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tensorflow-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# ...
# Using cached tensorflow-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/40.2 MB 3.8 MB/s eta 0:00:11
#    - -------------------------------------- 1.8/40.2 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/40.2 MB 3.7 MB/s eta 0:00:11
#    --- ------------------------------------ 3.1/40.2 MB 3.4 MB/s eta 0:00:11
#    --- ------------------------------------ 3.1/40.2 MB 3.4 MB/s eta 0:00:11
#    --- ------------------------------------ 3.1/40.2 MB 3.4 MB/s eta 0:00:11
#    --- ------------------------------------ 3.7/40.2 MB 2.4 MB/s eta 0:00:15
# ...
